# %%
import pandas as pd
import requests
import numpy as np

def get_ref_county(county, api_key):
# Out:
#   Cell In [1], line 5
#     def get_ref_county(county, api_key):
#                                         ^
# SyntaxError: incomplete input
