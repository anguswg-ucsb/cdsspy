# %%
import pandas as pd
import requests
import datetime

def get_telemetry_ts(
    abbrev              = None,
    parameter           = "DISCHRG",
    start_date          = None,
    end_date            = None,
    timescale           = "day",
    include_third_party = True,
    api_key             = None
    ):

    # if no abbreviation is given, return error
    if abbrev is None:
        return print("Invalid 'abbrev' parameter")

    #  base API URL
    base = "https://dwr.state.co.us/Rest/GET/api/v2/telemetrystations/telemetrytimeseries" + timescale + "/?"

    # if no start_date is given, default to 1900-01-01
    if start_date is None: 
        start_date = "1900-01-01"
        start_date = datetime.datetime.strptime(start_date, '%Y-%m-%d')
        start_date = start_date.strftime("%m-%d-%Y")
        start_date = start_date.replace("-", "%2F")
    else:
        start_date = datetime.datetime.strptime(start_date, '%Y-%m-%d')
        start_date = start_date.strftime("%m-%d-%Y")
        start_date = start_date.replace("-", "%2F")

    # print(start_date)

    # if no end date is given, default to current date
    if end_date is None: 
        end_date   = datetime.date.today()
        end_date   = end_date.strftime("%m-%d-%Y")
        end_date   = end_date.replace("-", "%2F")
    else:
        end_date   = datetime.datetime.strptime(end_date, '%Y-%m-%d')
        end_date   = end_date.strftime("%m-%d-%Y")
        end_date   = end_date.replace("-", "%2F")
        
    # print("Start date: " + start_date)
    # print("Start date: " + end_date)

    # Set correct name of date field for querying raw data
    if timescale == "raw": 
        # raw date field name
        date_field = "measDateTime"
    else:
        # hour and day date field name
        date_field = "measDate"
        
    # maximum records per page
    page_size  = 50000
    # page_size  = 1000

    # initialize empty dataframe to store data from multiple pages
    data_df    = pd.DataFrame()

    # initialize first page index
    page_index = 1

    # Loop through pages until there are no more pages to get
    more_pages = True

    # Loop through pages until last page of data is found, binding each responce dataframe together
    while more_pages == True:

        # create string tuple
        url = (base, 
        "format=json&dateFormat=spaceSepToSeconds&fields=abbrev%2Cparameter%2C", date_field, "%2CmeasValue%2CmeasUnit",
        "&abbrev=", abbrev,
        "&endDate=", end_date,
        "&startDate=", start_date,
        "&includeThirdParty=", str(include_third_party).lower(),
        "&parameter=", parameter,
        "&pageSize=", str(page_size),
        "&pageIndex=", str(page_index)
        )
        
        # join tuble into single string
        url = "".join(url)
        
        # If an API key is provided, add it to query URL
        if api_key is not None:
            # Construct query URL w/ API key
            url = url + "&apiKey=" + str(api_key)
      
        # make API call
        cdss_req = requests.get(url)
        
        # extract dataframe from list column
        cdss_df  = cdss_req.json() 
        cdss_df  = pd.DataFrame(cdss_df)
        cdss_df  = cdss_df["ResultList"].apply(pd.Series) 
        
        # bind data from this page
        data_df = pd.concat([data_df, cdss_df])
        
        # bind data from this page
        data_df = pd.concat([data_df, cdss_df])

        # convert measDateTime and measDate columns to 'date' and pd datetime type
        if timescale == "raw":
            # convert measDate column to datetime column
            data_df['date'] = pd.to_datetime(data_df['measDateTime'])

            # remove old measDate column
            del data_df['measDateTime']
        else: 
            # convert measDate column to datetime column
            data_df['date'] = pd.to_datetime(data_df['measDate'])
            
            # remove old measDate column
            del data_df['measDate']

        # Check if more pages to get to continue/stop while loop
        if(len(cdss_df.index) < page_size): 
            more_pages = False
        else:
            page_index += 1

    return data_df

# %%
import siuba

# %%
dis_ts = get_telemetry_ts(
    abbrev     = "CLAFTCCO",
    start_date = "2015-01-01",
    timescale  = "day"
)

# %%
dis_ts
# Out:
#         abbrev parameter  measValue measUnit       date
# 0     CLAFTCCO   DISCHRG        0.0      cfs 2015-01-01
# 1     CLAFTCCO   DISCHRG        0.0      cfs 2015-01-02
# 2     CLAFTCCO   DISCHRG        0.0      cfs 2015-01-03
# 3     CLAFTCCO   DISCHRG        0.0      cfs 2015-01-04
# 4     CLAFTCCO   DISCHRG        0.0      cfs 2015-01-05
# ...        ...       ...        ...      ...        ...
# 2762  CLAFTCCO   DISCHRG       51.4      cfs 2022-10-21
# 2763  CLAFTCCO   DISCHRG       48.3      cfs 2022-10-22
# 2764  CLAFTCCO   DISCHRG       50.8      cfs 2022-10-23
# 2765  CLAFTCCO   DISCHRG       52.4      cfs 2022-10-24
# 2766  CLAFTCCO   DISCHRG       50.8      cfs 2022-10-25
#
# [5534 rows x 5 columns]

# %%
tmp = siuba.filter(dis_ts, "measDate" == 2016-01-01)
# Out:
#   Cell In [11], line 1
#     tmp = siuba.filter(dis_ts, "measDate" == 2016-01-01)
#                                                   ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
df[(df['Date'] > "2018-01-01") & (df['Date'] < "2019-07-01")]

# %%
dis_ts.loc[datetime.date(year=2016,month=1,day=1):datetime.date(year=2017,month=2,day=1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6718, in Index.get_slice_bound(self, label, side, kind)
#    6717 try:
# -> 6718     slc = self.get_loc(label)
#    6719 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\range.py:396, in RangeIndex.get_loc(self, key, method, tolerance)
#     395     self._check_indexing_error(key)
# --> 396     raise KeyError(key)
#     397 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: datetime.date(2016, 1, 1)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 dis_ts.loc[datetime.date(year=2016,month=1,day=1):datetime.date(year=2017,month=2,day=1)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1291, in _LocIndexer._getitem_axis(self, key, axis)
#    1289 if isinstance(key, slice):
#    1290     self._validate_key(key, axis)
# -> 1291     return self._get_slice_axis(key, axis=axis)
#    1292 elif com.is_bool_indexer(key):
#    1293     return self._getbool_axis(key, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1325, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1322     return obj.copy(deep=False)
#    1324 labels = obj._get_axis(axis)
# -> 1325 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1327 if isinstance(indexer, slice):
#    1328     return self.obj._slice(indexer, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6597, in Index.slice_indexer(self, start, end, step, kind)
#    6554 """
#    6555 Compute the slice indexer for input labels and step.
#    6556
#    (...)
#    6593 slice(1, 3, None)
#    6594 """
#    6595 self._deprecated_arg(kind, "kind", "slice_indexer")
# -> 6597 start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6599 # return a slice
#    6600 if not is_scalar(start_slice):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6805, in Index.slice_locs(self, start, end, step, kind)
#    6803 start_slice = None
#    6804 if start is not None:
# -> 6805     start_slice = self.get_slice_bound(start, "left")
#    6806 if start_slice is None:
#    6807     start_slice = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6721, in Index.get_slice_bound(self, label, side, kind)
#    6719 except KeyError as err:
#    6720     try:
# -> 6721         return self._searchsorted_monotonic(label, side)
#    6722     except ValueError:
#    6723         # raise the original KeyError
#    6724         raise err
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6667, in Index._searchsorted_monotonic(self, label, side)
#    6665 def _searchsorted_monotonic(self, label, side: Literal["left", "right"] = "left"):
#    6666     if self.is_monotonic_increasing:
# -> 6667         return self.searchsorted(label, side=side)
#    6668     elif self.is_monotonic_decreasing:
#    6669         # np.searchsorted expects ascending sort order, have to reverse
#    6670         # everything for it to work (element ordering, search side and
#    6671         # resulting value).
#    6672         pos = self[::-1].searchsorted(
#    6673             label, side="right" if side == "left" else "left"
#    6674         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\base.py:1298, in IndexOpsMixin.searchsorted(self, value, side, sorter)
#    1294 if not isinstance(values, np.ndarray):
#    1295     # Going through EA.searchsorted directly improves performance GH#38083
#    1296     return values.searchsorted(value, side=side, sorter=sorter)
# -> 1298 return algorithms.searchsorted(
#    1299     values,
#    1300     value,
#    1301     side=side,
#    1302     sorter=sorter,
#    1303 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\algorithms.py:1662, in searchsorted(arr, value, side, sorter)
#    1658     arr = ensure_wrapped_if_datetimelike(arr)
#    1660 # Argument 1 to "searchsorted" of "ndarray" has incompatible type
#    1661 # "Union[NumpyValueArrayLike, ExtensionArray]"; expected "NumpyValueArrayLike"
# -> 1662 return arr.searchsorted(value, side=side, sorter=sorter)
#
# TypeError: '<' not supported between instances of 'int' and 'datetime.date'

# %%
dis_ts.loc['2016-01-01']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 dis_ts.loc['2016-01-01']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1313, in _LocIndexer._getitem_axis(self, key, axis)
#    1311 # fall thru to straight lookup
#    1312 self._validate_key(key, axis)
# -> 1313 return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1261, in _LocIndexer._get_label(self, label, axis)
#    1259 def _get_label(self, label, axis: int):
#    1260     # GH#5567 this will fail if the label is not present in the axis.
# -> 1261     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:4057, in NDFrame.xs(self, key, axis, level, drop_level)
#    4055             new_index = index[loc]
#    4056 else:
# -> 4057     loc = index.get_loc(key)
#    4059     if isinstance(loc, np.ndarray):
#    4060         if loc.dtype == np.bool_:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\range.py:396, in RangeIndex.get_loc(self, key, method, tolerance)
#     394             raise KeyError(key) from err
#     395     self._check_indexing_error(key)
# --> 396     raise KeyError(key)
#     397 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: '2016-01-01'
